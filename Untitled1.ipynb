# %%
# %pip install langgraph langsmith langchain langchain_groq langchain_community
# Out:
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.0.7)
# Requirement already satisfied: langsmith in /usr/local/lib/python3.12/dist-packages (0.6.6)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.7)
# Collecting langchain_groq
#   Downloading langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.3.3)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langgraph) (2.12.3)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith) (3.11.5)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langsmith) (25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (2.32.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (0.14.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (0.25.0)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.2.8-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.46)
# Collecting requests>=2.0.0 (from langsmith)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.5 MB/s eta 0:00:00
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.0 MB/s eta 0:00:00
# Downloading langchain_core-1.2.8-py3-none-any.whl (495 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.8/495.8 kB 34.8 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.2 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, mypy-extensions, marshmallow, typing-inspect, groq, dataclasses-json, langchain-core, langchain-text-splitters, langchain_groq, langchain-classic, langchain_community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.7
#     Uninstalling langchain-core-1.2.7:
#       Successfully uninstalled langchain-core-1.2.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 groq-0.37.1 langchain-classic-1.0.1 langchain-core-1.2.8 langchain-text-splitters-1.1.0 langchain_community-0.4.1 langchain_groq-1.1.2 marshmallow-3.26.2 mypy-extensions-1.1.0 requests-2.32.5 typing-inspect-0.9.0

# %%
from typing import Annotated
from typing_extensions import TypedDict

# %%
# %pip install arxiv wikipedia
# Out:
# Collecting arxiv
#   Downloading arxiv-2.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting feedparser~=6.0.10 (from arxiv)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: requests~=2.32.0 in /usr/local/lib/python3.12/dist-packages (from arxiv) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from wikipedia) (4.13.5)
# Collecting sgmllib3k (from feedparser~=6.0.10->arxiv)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.0->arxiv) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.0->arxiv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.0->arxiv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.0->arxiv) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->wikipedia) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Downloading arxiv-2.4.0-py3-none-any.whl (12 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: wikipedia, sgmllib3k
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=f58186fa0089317d04b6f9e9b189b066b94b240d45b0a33ca49f02d8d46bf678
#   Stored in directory: /root/.cache/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=59d0fb8de5969ce92d7f25ddd499286ec178ea651d242cef6567338f6d0ab15d
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built wikipedia sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, wikipedia, arxiv
# Successfully installed arxiv-2.4.0 feedparser-6.0.12 sgmllib3k-1.0.0 wikipedia-1.4.0

# %%
## Working With Tools

from langchain_community.utilities import ArxivAPIWrapper,WikipediaAPIWrapper
from langchain_community.tools import ArxivQueryRun,WikipediaQueryRun

## Arxiv And Wikipedia tools
arxiv_wrapper=ArxivAPIWrapper(top_k_results=1,doc_content_chars_max=300)
arxiv_tool=ArxivQueryRun(api_wrapper=arxiv_wrapper)

api_wrapper=WikipediaAPIWrapper(top_k_results=1,doc_content_chars_max=300)
wiki_tool=WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
wiki_tool.invoke("who was micheal jackson")
# Out:
# 'Page: Michael Jackson\nSummary: Michael Joseph Jackson (August 29, 1958 – June 25, 2009) was an American singer, songwriter, dancer, and philanthropist. Dubbed the "King of Pop", he is widely regarded as one of the most culturally significant figures of the 20th century. Over a four-decade career, hi'

# %%
arxiv_tool.invoke("what is in name")
# Out:
# 'Published: 2026-01-07\nTitle: Name That Part: 3D Part Segmentation and Naming\nAuthors: Soumava Paul, Prakhar Kaushik, Ankit Vaidya, Anand Bhattad, Alan Yuille\nSummary: We address semantic 3D part segmentation: decomposing objects into parts with meaningful names. While datasets exist with part annota'

# %%
tools=[wiki_tool]

# %%
## Langgraph Application
from langgraph.graph.message import add_messages
class State(TypedDict):
  messages:Annotated[list,add_messages]

# %%
from langgraph.graph import StateGraph,START,END

# %%
graph_builder= StateGraph(State)

# %%
from langchain_groq import ChatGroq

# %%
from google.colab import userdata
groq_api_key=userdata.get("Groq_API_Keys")

# %%
llm=ChatGroq(groq_api_key=groq_api_key,model_name="openai/gpt-oss-120b")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x7eb524883050>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7eb524879400>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
llm_with_tools=llm.bind_tools(tools=tools)

# %%
def chatbot(state:State):
  return {"messages":[llm_with_tools.invoke(state["messages"])]}

# %%
from langgraph.prebuilt import ToolNode,tools_condition

# %%
graph_builder.add_node("chatbot",chatbot)
tool_node = ToolNode(tools=tools)
graph_builder.add_node("tools", tool_node)

graph_builder.add_conditional_edges(
    "chatbot",
    tools_condition,
)
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START,"chatbot")
# Out:
# WARNING:langgraph.graph.state:Adding a node to a graph that has already been compiled. This will not be reflected in the compiled graph.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-992953321.py in <cell line: 0>()
# ----> 1 graph_builder.add_node("chatbot",chatbot)
#       2 tool_node = ToolNode(tools=tools)
#       3 graph_builder.add_node("tools", tool_node)
#       4
#       5 graph_builder.add_conditional_edges(
#
# /usr/local/lib/python3.12/dist-packages/langgraph/graph/state.py in add_node(self, node, action, defer, metadata, input_schema, retry_policy, cache_policy, destinations, **kwargs)
#     475             raise RuntimeError
#     476         if node in self.nodes:
# --> 477             raise ValueError(f"Node `{node}` already present.")
#     478         if node == END or node == START:
#     479             raise ValueError(f"Node `{node}` is reserved.")
#
# ValueError: Node `chatbot` already present.

# %%
graph=graph_builder.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
user_input="Hi there!, My name is raj"

events=graph.stream(
     {"messages": [("user", user_input)]},stream_mode="values"
)

for event in events:
  event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hi there!, My name is raj
# ================================== Ai Message ==================================
#
# Hi Raj! 👋 Nice to meet you. How can I assist you today?

# %%
user_input = "what is RLHF."

# The config is the **second positional argument** to stream() or invoke()!
events = graph.stream(
    {"messages": [("user", user_input)]},stream_mode="values"
)
for event in events:
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# what is RLHF.
# ================================== Ai Message ==================================
#
# **RLHF — Reinforcement Learning from Human Feedback**
#
# ---
#
# ### 1. What the acronym stands for
# **RLHF** = **Reinforcement Learning from Human Feedback**.
# It is a training paradigm that combines reinforcement learning (RL) with supervision derived from human judgments rather than a hand‑crafted reward function.
#
# ---
#
# ### 2. Why it was invented
# - **Hard‑to‑specify objectives**: Many tasks (e.g., generating helpful, truthful, or safe language) are difficult to capture with a simple mathematical reward.
# - **Alignment**: For powerful models (especially large language models), we want their behavior to reflect human values and preferences.
# - **Sample efficiency**: Pure RL with a simulated environment often requires millions of interactions; human feedback can guide the agent much more quickly toward desirable behavior.
#
# ---
#
# ### 3. Core pipeline (high‑level)
#
# | Step | What happens | Typical techniques |
# |------|--------------|---------------------|
# | **a. Pre‑training** | Train a large model on massive unsupervised data (e.g., next‑token prediction for LLMs). | Transformer‑based language models, vision models, etc. |
# | **b. Collect human feedback** | Humans evaluate model outputs (ranking, binary preference, or scalar rating). | Pairwise comparisons, Likert scales, “thumbs‑up/down”. |
# | **c. Train a **reward model** (RM)** | Use the collected feedback to fit a supervised model that predicts the human‑provided score for any candidate output. | Binary cross‑entropy on pairwise data, regression on scalar scores. |
# | **d. Reinforcement‑learning fine‑tuning** | The original model (now called the **policy**) is optimized to maximize the reward model’s predictions. | PPO (Proximal Policy Optimization) is most common; other RL algorithms (A2C, REINFORCE) are also used. |
# | **e. Iteration / refinement** | Optionally repeat steps b‑d with newer model outputs, expanding the feedback dataset. | “RLHF loop”, active learning to focus on failure modes. |
#
# ---
#
# ### 4. Formal sketch
#
# 1. **Reward model** \(R_\phi\) :
#    \[
#    R_\phi(x, y) \approx \mathbb{E}[\text{human preference} \mid \text{prompt } x, \text{response } y]
#    \]
# 2. **Policy** \(\pi_\theta\) (the generative model) is updated to maximize expected reward:
#    \[
#    \max_\theta \; \mathbb{E}_{x\sim D,\; y\sim \pi_\theta(\cdot|x)}[R_\phi(x, y)] - \beta \, \text{KL}(\pi_\theta \,\|\, \pi_{\text{pre‑trained}})
#    \]
#    The KL term (with coefficient \(\beta\)) keeps the fine‑tuned policy close to the original model, preventing it from drifting into pathological behavior.
#
# ---
#
# ### 5. Key ingredients & tricks
#
# | Ingredient | Why it matters | Typical choices |
# |------------|----------------|-----------------|
# | **Human data format** | Pairwise comparisons are more reliable than absolute scores. | “Which of A or B is better?” |
# | **Reward model architecture** | Should be compatible with the policy (often a smaller version of the same transformer). | Same tokeniser, shared embeddings. |
# | **KL‑penalty** | Prevents the policy from exploiting quirks of the reward model (reward hacking). | Fixed coefficient, or a dynamic schedule. |
# | **PPO clipping** | Stabilizes policy updates in high‑dimensional output spaces. | Clip range 0.1–0.2. |
# | **Safety filters** | Additional post‑processing to block disallowed content. | Rule‑based or separate classifier. |
# | **Curriculum / active learning** | Focuses human effort on the most ambiguous or risky examples. | Uncertainty sampling, disagreement among policies. |
#
# ---
#
# ### 6. Prominent applications
#
# | Domain | What RLHF achieves |
# |--------|--------------------|
# | **Large Language Models (LLMs)** | More helpful, less toxic, better instruction following (e.g., ChatGPT, Claude, Gemini). |
# | **Robotics** | Teach robots tasks where reward shaping is hard (e.g., household chores) by letting humans rank trajectories. |
# | **Dialogue systems** | Align conversational agents with user satisfaction and ethical guidelines. |
# | **Content moderation** | Train classifiers to prefer safe outputs while preserving usefulness. |
# | **Game AI** | Human‑rated gameplay clips guide agents toward human‑like strategies. |
#
# ---
#
# ### 7. Advantages
#
# 1. **Alignment with human values** – Directly incorporates what people consider “good”.
# 2. **Flexibility** – Works for any task where you can collect preference data, even if the objective is vague.
# 3. **Sample efficiency** – A few thousand human judgments can dramatically improve a model that already knows the basics.
#
# ---
#
# ### 8. Known challenges & open research
#
# | Challenge | Description | Current mitigations |
# |-----------|-------------|---------------------|
# | **Reward model over‑fitting / bias** | The RM may learn spurious cues (e.g., length, punctuation). | Regularization, cross‑validation, diverse annotator pool. |
# | **Reward hacking** | Policy finds loopholes that maximize the RM but violate true intent. | KL penalty, multi‑objective RL, periodic human re‑evaluation. |
# | **Scalability of human labeling** | High‑quality feedback is expensive. | Semi‑automated labeling, active learning, synthetic preference generation. |
# | **Distribution shift** | After RL fine‑tuning, the policy may produce outputs outside the RM’s training distribution. | Online RLHF loops, out‑of‑distribution detection. |
# | **Interpretability** | Hard to know why the policy prefers a certain output. | Probe the RM, use attribution methods, visualize attention. |
# | **Safety & robustness** | Even RLHF‑trained models can produce harmful content in edge cases. | Post‑hoc safety classifiers, constitutional AI, adversarial testing. |
#
# ---
#
# ### 9. Example (simplified)
#
# 1. **Prompt**: “Explain why the sky is blue.”
# 2. **Two model outputs**:
#    - *A*: “The sky appears blue because molecules scatter shorter wavelengths of sunlight more than longer wavelengths.”
#    - *B*: “The sky is blue because that’s the color we see most often.”
# 3. **Human annotator** selects *A* as better.
# 4. **Reward model** learns to give higher scores to outputs similar to *A*.
# 5. **Policy** is updated via PPO to increase the probability of generating *A*-like responses for future prompts.
#
# ---
#
# ### 10. TL;DR
#
# - **RLHF** = Reinforcement Learning from Human Feedback.
# - It augments a pre‑trained model with a **reward model** trained on **human preference data**, then fine‑tunes the policy using **RL (usually PPO)** to maximize that reward while staying close to the original model.
# - The technique is the backbone of today’s most capable, instruction‑following AI systems, but it still faces challenges like reward hacking, label cost, and safety guarantees.
#
# Feel free to ask for deeper details on any component (e.g., PPO specifics, reward‑model training, safety mechanisms, or code snippets).
